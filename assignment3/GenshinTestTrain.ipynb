# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.svm import SVC
import numpy as np
from sklearn import svm
from sklearn.metrics import accuracy_score as ac

# using the genshin banner revenue dataset obtained by my group
dt = pd.read_excel("GenshinBannerRev.xlsx")
dt.dropna(inplace=True)

# %%
#revenue class is divided into 'Above average' (revenue > average revenue), 'Below average'
dt["Revenue_Class"] = np.where(dt["Revenue"]>dt["Revenue"].mean(), "Above Average", "Below Average")
dt.info()
dt
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 35
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Version            36 non-null     float64
#  1   Version Name       36 non-null     object
#  2   Start Date         36 non-null     object
#  3   End Date           36 non-null     object
#  4   5 Star Characters  36 non-null     object
#  5   Rerun              36 non-null     float64
#  6   Mixed              36 non-null     object
#  7   Revenue            36 non-null     float64
#  8   Banner Days        36 non-null     float64
#  9   Avg Revenue/Day    36 non-null     float64
#  10  Revenue_Class      36 non-null     object
# dtypes: float64(5), object(6)
# memory usage: 3.4+ KB
#     Version                            Version Name           Start Date  \
# 0       1.0                       Welcome to Tevyat           25/09/2020
# ...

# %%
x=dt.iloc[10:21,[0,5,6,8]]
y=dt.loc[10:20,'Revenue_Class']
print(x)
print(y)

#gives 100% accuracy score with this kernel rbf setting (gamma 2.0 and C 20.9)
svm = SVC(kernel= "rbf", random_state=1, gamma=2, C=20.9)

svm.fit(x, y)
y_predict=svm.predict(x)

print(ac(y, y_predict))
# Out:
#     Version  Rerun Mixed  Banner Days
# 10      1.4    1.0   0.0         21.0
# 11      1.5    1.0   0.0         21.0
# 12      1.5    0.0   0.0         21.0
# 13      1.6    1.0   0.0         21.0
# 14      1.6    0.0   0.0         21.0
# 15      2.0    0.0   0.0         21.0
# 16      2.0    0.0   0.0         21.0
# 17      2.1    0.0   0.0         20.0
# 18      2.1    0.0   0.0         22.0
# 19      2.2    1.0   0.0         21.0
# 20      2.2    1.0   0.0         22.0
# 10    Below Average
# 11    Below Average
# 12    Below Average
# 13    Below Average
# 14    Below Average
# 15    Below Average
# 16    Below Average
# 17    Above Average
# 18    Below Average
# 19    Below Average
# 20    Above Average
# Name: Revenue_Class, dtype: object
# 1.0

# %%
#splitting data
feature_col = ["Revenue"]
x = dt[feature_col]
y = dt["Revenue_Class"]

#Dividing it into train set data and test set data.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.5, random_state = 9)

#checking the train and test data
x_train
y_train
x_test
y_test
# Out:
# 19    Below Average
# 4     Below Average
# 15    Below Average
# 2     Below Average
# 13    Below Average
# 32    Below Average
# 31    Above Average
# 30    Below Average
# 29    Above Average
# 23    Below Average
# 9     Below Average
# 7     Below Average
# 6     Below Average
# 16    Below Average
# 5     Below Average
# 11    Below Average
# 3     Below Average
# 35    Below Average
# Name: Revenue_Class, dtype: object

# %%
#SVM settings
svm = SVC(kernel='rbf', random_state=1, gamma= 0.7, C=0.7)

#training the model
svm.fit(x_train, y_train)

#predicting the train set
y_pred=svm.predict(x_train)

print("Accuracy Score = "+ str(accuracy_score(y_train, y_pred)))
# Out:
# Accuracy Score = 1.0

# %%
#predicting the test set
y_pred2=svm.predict(x_test)

#printing the train set accuracy score
print("Accuracy Score = " + str(accuracy_score(y_test, y_pred2)))
# Out:
# Accuracy Score = 0.8888888888888888

# %%
#Comparing train and data set
#Train set score: 100%
#test set score: 88%
#To conclude: The train set score appears to be higher than the accuracy of test set score. The accuracy for the test set score could definitely improve if more data is to be trained and put into the test.Thus this may be considered overfitting and has not reached our expected standards as we aim for the score to be above 95%.
